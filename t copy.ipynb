# %%
import tensorflow as tf
from tensorflow import keras

import numpy as np
import matplotlib.pyplot as plt

##############################################################################################################################

NUM_WORDS = 1000

(train_data, train_labels), (test_data, test_labels) = keras.datasets.imdb.load_data(num_words=NUM_WORDS)

def multi_hot_sequences(sequences, dimension):
    # 0으로 채워진 (len(sequences), dimension) 크기의 행렬을 만듭니다
    results = np.zeros((len(sequences), dimension))
    for i, word_indices in enumerate(sequences):
        results[i, word_indices] = 1.0  # results[i]의 특정 인덱스만 1로 설정합니다
    return results


train_data = multi_hot_sequences(train_data, dimension=NUM_WORDS)
test_data = multi_hot_sequences(test_data, dimension=NUM_WORDS)

###########################################################################################################################################

baseline_model = keras.Sequential([
    # `.summary` 메서드 때문에 `input_shape`가 필요합니다
    keras.layers.Dense(16, activation='relu', input_shape=(NUM_WORDS,)),
    keras.layers.Dense(16, activation='relu'),
    keras.layers.Dense(1, activation='sigmoid')
])

baseline_model.compile(optimizer='adam',
                       loss='binary_crossentropy',
                       metrics=['accuracy', 'binary_crossentropy'])

baseline_history = baseline_model.fit(train_data,
                                      train_labels,
                                      epochs=20,
                                      batch_size=512,
                                      validation_data=(test_data, test_labels),
                                      verbose=2)

###########################################################################################################################################                                   

bigger_model = keras.models.Sequential([
    keras.layers.Dense(512, activation='relu', input_shape=(NUM_WORDS,)),
    keras.layers.Dense(512, activation='relu'),
    keras.layers.Dense(1, activation='sigmoid')
])

bigger_model.compile(optimizer='adam',
                     loss='binary_crossentropy',
                     metrics=['accuracy','binary_crossentropy'])


bigger_history = bigger_model.fit(train_data, train_labels,
                                  epochs=20,
                                  batch_size=512,
                                  validation_data=(test_data, test_labels),
                                  verbose=2)

###########################################################################################################################################

def plot_history(histories, key='binary_crossentropy'):
  plt.figure(figsize=(16,10))

  for name, history in histories:
    val = plt.plot(history.epoch, history.history['val_'+key],
                   '--', label=name.title()+' Val')
    plt.plot(history.epoch, history.history[key], color=val[0].get_color(),
             label=name.title()+' Train')

  plt.xlabel('Epochs')
  plt.ylabel(key.replace('_',' ').title())
  plt.legend()

  plt.xlim([0,max(history.epoch)])


plot_history([('baseline', baseline_history),              
              ('bigger', bigger_history)])
# Out:
# C:\Users\jp_desk\Miniconda3\envs\tf_env\lib\site-packages\tensorflow\python\framework\dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\jp_desk\Miniconda3\envs\tf_env\lib\site-packages\tensorflow\python\framework\dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\jp_desk\Miniconda3\envs\tf_env\lib\site-packages\tensorflow\python\framework\dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\jp_desk\Miniconda3\envs\tf_env\lib\site-packages\tensorflow\python\framework\dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\jp_desk\Miniconda3\envs\tf_env\lib\site-packages\tensorflow\python\framework\dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\jp_desk\Miniconda3\envs\tf_env\lib\site-packages\tensorflow\python\framework\dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# C:\Users\jp_desk\Miniconda3\envs\tf_env\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\jp_desk\Miniconda3\envs\tf_env\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\jp_desk\Miniconda3\envs\tf_env\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\jp_desk\Miniconda3\envs\tf_env\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\jp_desk\Miniconda3\envs\tf_env\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\jp_desk\Miniconda3\envs\tf_env\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/imdb.npz
# 17465344/17464789 [==============================] - 1s 0us/step
# C:\Users\jp_desk\Miniconda3\envs\tf_env\lib\site-packages\tensorflow\python\keras\datasets\imdb.py:128: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   x_train, y_train = np.array(xs[:idx]), np.array(labels[:idx])
# C:\Users\jp_desk\Miniconda3\envs\tf_env\lib\site-packages\tensorflow\python\keras\datasets\imdb.py:129: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   x_test, y_test = np.array(xs[idx:]), np.array(labels[idx:])
# WARNING:tensorflow:From C:\Users\jp_desk\Miniconda3\envs\tf_env\lib\site-packages\tensorflow\python\ops\init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From C:\Users\jp_desk\Miniconda3\envs\tf_env\lib\site-packages\tensorflow\python\ops\nn_impl.py:180: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Train on 25000 samples, validate on 25000 samples
# Epoch 1/20
# 25000/25000 - 1s - loss: 0.5702 - acc: 0.7111 - binary_crossentropy: 0.5702 - val_loss: 0.4217 - val_acc: 0.8190 - val_binary_crossentropy: 0.4217
# Epoch 2/20
# 25000/25000 - 1s - loss: 0.3639 - acc: 0.8480 - binary_crossentropy: 0.3639 - val_loss: 0.3579 - val_acc: 0.8491 - val_binary_crossentropy: 0.3579
# Epoch 3/20
# 25000/25000 - 1s - loss: 0.3225 - acc: 0.8674 - binary_crossentropy: 0.3225 - val_loss: 0.3321 - val_acc: 0.8580 - val_binary_crossentropy: 0.3321
# Epoch 4/20
# 25000/25000 - 1s - loss: 0.3103 - acc: 0.8725 - binary_crossentropy: 0.3103 - val_loss: 0.3296 - val_acc: 0.8593 - val_binary_crossentropy: 0.3296
# Epoch 5/20
# 25000/25000 - 1s - loss: 0.3026 - acc: 0.8754 - binary_crossentropy: 0.3026 - val_loss: 0.3297 - val_acc: 0.8598 - val_binary_crossentropy: 0.3297
# Epoch 6/20
# 25000/25000 - 1s - loss: 0.2993 - acc: 0.8775 - binary_crossentropy: 0.2993 - val_loss: 0.3316 - val_acc: 0.8592 - val_binary_crossentropy: 0.3316
# Epoch 7/20
# 25000/25000 - 1s - loss: 0.2949 - acc: 0.8784 - binary_crossentropy: 0.2949 - val_loss: 0.3302 - val_acc: 0.8583 - val_binary_crossentropy: 0.3302
# Epoch 8/20
# 25000/25000 - 1s - loss: 0.2897 - acc: 0.8800 - binary_crossentropy: 0.2897 - val_loss: 0.3328 - val_acc: 0.8590 - val_binary_crossentropy: 0.3328
# Epoch 9/20
# 25000/25000 - 1s - loss: 0.2853 - acc: 0.8837 - binary_crossentropy: 0.2853 - val_loss: 0.3371 - val_acc: 0.8568 - val_binary_crossentropy: 0.3371
# Epoch 10/20
# 25000/25000 - 1s - loss: 0.2771 - acc: 0.8872 - binary_crossentropy: 0.2771 - val_loss: 0.3367 - val_acc: 0.8584 - val_binary_crossentropy: 0.3367
# Epoch 11/20
# 25000/25000 - 1s - loss: 0.2696 - acc: 0.8902 - binary_crossentropy: 0.2696 - val_loss: 0.3373 - val_acc: 0.8584 - val_binary_crossentropy: 0.3373
# Epoch 12/20
# 25000/25000 - 1s - loss: 0.2625 - acc: 0.8922 - binary_crossentropy: 0.2625 - val_loss: 0.3407 - val_acc: 0.8552 - val_binary_crossentropy: 0.3407
# Epoch 13/20
# 25000/25000 - 1s - loss: 0.2559 - acc: 0.8972 - binary_crossentropy: 0.2559 - val_loss: 0.3475 - val_acc: 0.8548 - val_binary_crossentropy: 0.3475
# Epoch 14/20
# 25000/25000 - 1s - loss: 0.2486 - acc: 0.9003 - binary_crossentropy: 0.2486 - val_loss: 0.3522 - val_acc: 0.8530 - val_binary_crossentropy: 0.3522
# Epoch 15/20
# 25000/25000 - 1s - loss: 0.2428 - acc: 0.9020 - binary_crossentropy: 0.2428 - val_loss: 0.3552 - val_acc: 0.8514 - val_binary_crossentropy: 0.3552
# Epoch 16/20
# 25000/25000 - 1s - loss: 0.2368 - acc: 0.9041 - binary_crossentropy: 0.2368 - val_loss: 0.3644 - val_acc: 0.8479 - val_binary_crossentropy: 0.3644
# Epoch 17/20
# 25000/25000 - 1s - loss: 0.2297 - acc: 0.9068 - binary_crossentropy: 0.2297 - val_loss: 0.3678 - val_acc: 0.8479 - val_binary_crossentropy: 0.3678
# Epoch 18/20
# 25000/25000 - 1s - loss: 0.2234 - acc: 0.9108 - binary_crossentropy: 0.2234 - val_loss: 0.3739 - val_acc: 0.8489 - val_binary_crossentropy: 0.3739
# Epoch 19/20
# 25000/25000 - 1s - loss: 0.2180 - acc: 0.9126 - binary_crossentropy: 0.2180 - val_loss: 0.3866 - val_acc: 0.8485 - val_binary_crossentropy: 0.3866
# Epoch 20/20
# 25000/25000 - 1s - loss: 0.2107 - acc: 0.9151 - binary_crossentropy: 0.2107 - val_loss: 0.3893 - val_acc: 0.8457 - val_binary_crossentropy: 0.3893
# Train on 25000 samples, validate on 25000 samples
# Epoch 1/20
# 25000/25000 - 3s - loss: 0.4377 - acc: 0.7880 - binary_crossentropy: 0.4377 - val_loss: 0.3356 - val_acc: 0.8550 - val_binary_crossentropy: 0.3356
# Epoch 2/20
# 25000/25000 - 3s - loss: 0.2917 - acc: 0.8806 - binary_crossentropy: 0.2917 - val_loss: 0.3244 - val_acc: 0.8609 - val_binary_crossentropy: 0.3244
# Epoch 3/20
# 25000/25000 - 3s - loss: 0.2293 - acc: 0.9067 - binary_crossentropy: 0.2293 - val_loss: 0.3473 - val_acc: 0.8536 - val_binary_crossentropy: 0.3473
# Epoch 4/20
# 25000/25000 - 3s - loss: 0.1101 - acc: 0.9662 - binary_crossentropy: 0.1101 - val_loss: 0.4350 - val_acc: 0.8400 - val_binary_crossentropy: 0.4350
# Epoch 5/20
# 25000/25000 - 3s - loss: 0.0250 - acc: 0.9959 - binary_crossentropy: 0.0250 - val_loss: 0.5494 - val_acc: 0.8453 - val_binary_crossentropy: 0.5494
# Epoch 6/20
# 25000/25000 - 3s - loss: 0.0048 - acc: 0.9996 - binary_crossentropy: 0.0048 - val_loss: 0.6249 - val_acc: 0.8503 - val_binary_crossentropy: 0.6249
# Epoch 7/20
# 25000/25000 - 3s - loss: 0.0011 - acc: 1.0000 - binary_crossentropy: 0.0011 - val_loss: 0.6707 - val_acc: 0.8506 - val_binary_crossentropy: 0.6707
# Epoch 8/20
# 25000/25000 - 3s - loss: 5.5381e-04 - acc: 1.0000 - binary_crossentropy: 5.5381e-04 - val_loss: 0.7022 - val_acc: 0.8511 - val_binary_crossentropy: 0.7022
# Epoch 9/20
# 25000/25000 - 3s - loss: 3.8777e-04 - acc: 1.0000 - binary_crossentropy: 3.8777e-04 - val_loss: 0.7232 - val_acc: 0.8511 - val_binary_crossentropy: 0.7232
# Epoch 10/20
# 25000/25000 - 3s - loss: 2.9266e-04 - acc: 1.0000 - binary_crossentropy: 2.9266e-04 - val_loss: 0.7411 - val_acc: 0.8518 - val_binary_crossentropy: 0.7411
# Epoch 11/20
# 25000/25000 - 3s - loss: 2.3081e-04 - acc: 1.0000 - binary_crossentropy: 2.3081e-04 - val_loss: 0.7588 - val_acc: 0.8514 - val_binary_crossentropy: 0.7588
# Epoch 12/20
# 25000/25000 - 3s - loss: 1.8564e-04 - acc: 1.0000 - binary_crossentropy: 1.8564e-04 - val_loss: 0.7741 - val_acc: 0.8514 - val_binary_crossentropy: 0.7741
# Epoch 13/20
# 25000/25000 - 3s - loss: 1.5254e-04 - acc: 1.0000 - binary_crossentropy: 1.5254e-04 - val_loss: 0.7889 - val_acc: 0.8513 - val_binary_crossentropy: 0.7889
# Epoch 14/20
# 25000/25000 - 3s - loss: 1.2634e-04 - acc: 1.0000 - binary_crossentropy: 1.2634e-04 - val_loss: 0.8020 - val_acc: 0.8514 - val_binary_crossentropy: 0.8020
# Epoch 15/20
# 25000/25000 - 3s - loss: 1.0595e-04 - acc: 1.0000 - binary_crossentropy: 1.0595e-04 - val_loss: 0.8155 - val_acc: 0.8512 - val_binary_crossentropy: 0.8155
# Epoch 16/20
# 25000/25000 - 3s - loss: 8.9432e-05 - acc: 1.0000 - binary_crossentropy: 8.9432e-05 - val_loss: 0.8283 - val_acc: 0.8512 - val_binary_crossentropy: 0.8283
# Epoch 17/20
# 25000/25000 - 3s - loss: 7.5978e-05 - acc: 1.0000 - binary_crossentropy: 7.5978e-05 - val_loss: 0.8406 - val_acc: 0.8513 - val_binary_crossentropy: 0.8406
# Epoch 18/20
# 25000/25000 - 3s - loss: 6.4896e-05 - acc: 1.0000 - binary_crossentropy: 6.4896e-05 - val_loss: 0.8530 - val_acc: 0.8511 - val_binary_crossentropy: 0.8530
# Epoch 19/20
# 25000/25000 - 3s - loss: 5.5852e-05 - acc: 1.0000 - binary_crossentropy: 5.5852e-05 - val_loss: 0.8642 - val_acc: 0.8515 - val_binary_crossentropy: 0.8642
# Epoch 20/20
# 25000/25000 - 3s - loss: 4.8268e-05 - acc: 1.0000 - binary_crossentropy: 4.8268e-05 - val_loss: 0.8761 - val_acc: 0.8514 - val_binary_crossentropy: 0.8761

# %%
import tensorflow as tf
from tensorflow import keras

import numpy as np
import matplotlib.pyplot as plt

###########################################################################################################################################

NUM_WORDS = 1000

(train_data, train_labels), (test_data, test_labels) = keras.datasets.imdb.load_data(num_words=NUM_WORDS)

def multi_hot_sequences(sequences, dimension):
    # 0으로 채워진 (len(sequences), dimension) 크기의 행렬을 만듭니다
    results = np.zeros((len(sequences), dimension))
    for i, word_indices in enumerate(sequences):
        results[i, word_indices] = 1.0  # results[i]의 특정 인덱스만 1로 설정합니다
    return results


train_data = multi_hot_sequences(train_data, dimension=NUM_WORDS)
test_data = multi_hot_sequences(test_data, dimension=NUM_WORDS)

###########################################################################################################################################

baseline_model = keras.Sequential([
    # `.summary` 메서드 때문에 `input_shape`가 필요합니다
    keras.layers.Dense(16, activation='relu', input_shape=(NUM_WORDS,)),
    keras.layers.Dense(16, activation='relu'),
    keras.layers.Dense(1, activation='sigmoid')
])

baseline_model.compile(optimizer='adam',
                       loss='binary_crossentropy',
                       metrics=['accuracy', 'binary_crossentropy'])

baseline_history = baseline_model.fit(train_data,
                                      train_labels,
                                      epochs=20,
                                      batch_size=512,
                                      validation_data=(test_data, test_labels),
                                      verbose=2)

###########################################################################################################################################

bigger_model = keras.models.Sequential([
    keras.layers.Dense(512, activation='relu', input_shape=(NUM_WORDS,)),
    keras.layers.Dense(512, activation='relu'),
    keras.layers.Dense(1, activation='sigmoid')
])

bigger_model.compile(optimizer='adam',
                     loss='binary_crossentropy',
                     metrics=['accuracy','binary_crossentropy'])


bigger_history = bigger_model.fit(train_data, train_labels,
                                  epochs=20,
                                  batch_size=512,
                                  validation_data=(test_data, test_labels),
                                  verbose=2)

###########################################################################################################################################

BN_bigger_model = keras.models.Sequential([
                                           
tf.keras.layers.BatchNormalization
(
    axis=-1,
    momentum=0.99,
    epsilon=0.001,
    center=True,
    scale=True,
    beta_initializer='zeros',
    gamma_initializer='ones',
    moving_mean_initializer='zeros',
    moving_variance_initializer='ones',
    beta_regularizer=None,
    gamma_regularizer=None,
    beta_constraint=None,
    gamma_constraint=None,
    
),
    keras.layers.Dense(512, activation='relu', input_shape=(NUM_WORDS,)),
    keras.layers.Dense(512, activation='relu'),
    keras.layers.Dense(1, activation='sigmoid')
])

BN_bigger_model.compile(optimizer='adam',
                     loss='binary_crossentropy',
                     metrics=['accuracy','binary_crossentropy'])


BN_bigger_history = BN_bigger_model.fit(train_data, train_labels,
                                  epochs=20,
                                  batch_size=512,
                                  validation_data=(test_data, test_labels),
                                  verbose=2)

###########################################################################################################################################

def plot_history(histories, key='binary_crossentropy'):
  plt.figure(figsize=(16,10))

  for name, history in histories:
    val = plt.plot(history.epoch, history.history['val_'+key],
                   '--', label=name.title()+' Val')
    plt.plot(history.epoch, history.history[key], color=val[0].get_color(),
             label=name.title()+' Train')

  plt.xlabel('Epochs')
  plt.ylabel(key.replace('_',' ').title())
  plt.legend()

  plt.xlim([0,max(history.epoch)])


plot_history([('baseline', baseline_history),              
              ('bigger', bigger_history),
              ('BN_bigger', BN_bigger_history)])
# Out:
# Train on 25000 samples, validate on 25000 samples
# Epoch 1/20
# 25000/25000 - 1s - loss: 0.6314 - acc: 0.6439 - binary_crossentropy: 0.6314 - val_loss: 0.5247 - val_acc: 0.8005 - val_binary_crossentropy: 0.5247
# Epoch 2/20
# 25000/25000 - 1s - loss: 0.4311 - acc: 0.8385 - binary_crossentropy: 0.4311 - val_loss: 0.3756 - val_acc: 0.8492 - val_binary_crossentropy: 0.3756
# Epoch 3/20
# 25000/25000 - 1s - loss: 0.3414 - acc: 0.8612 - binary_crossentropy: 0.3414 - val_loss: 0.3366 - val_acc: 0.8601 - val_binary_crossentropy: 0.3366
# Epoch 4/20
# 25000/25000 - 1s - loss: 0.3180 - acc: 0.8700 - binary_crossentropy: 0.3180 - val_loss: 0.3299 - val_acc: 0.8606 - val_binary_crossentropy: 0.3299
# Epoch 5/20
# 25000/25000 - 1s - loss: 0.3070 - acc: 0.8734 - binary_crossentropy: 0.3070 - val_loss: 0.3273 - val_acc: 0.8608 - val_binary_crossentropy: 0.3273
# Epoch 6/20
# 25000/25000 - 1s - loss: 0.3028 - acc: 0.8756 - binary_crossentropy: 0.3028 - val_loss: 0.3278 - val_acc: 0.8608 - val_binary_crossentropy: 0.3278
# Epoch 7/20
# 25000/25000 - 1s - loss: 0.2997 - acc: 0.8760 - binary_crossentropy: 0.2997 - val_loss: 0.3267 - val_acc: 0.8606 - val_binary_crossentropy: 0.3267
# Epoch 8/20
# 25000/25000 - 1s - loss: 0.2978 - acc: 0.8758 - binary_crossentropy: 0.2978 - val_loss: 0.3275 - val_acc: 0.8602 - val_binary_crossentropy: 0.3275
# Epoch 9/20
# 25000/25000 - 0s - loss: 0.2966 - acc: 0.8782 - binary_crossentropy: 0.2966 - val_loss: 0.3279 - val_acc: 0.8606 - val_binary_crossentropy: 0.3279
# Epoch 10/20
# 25000/25000 - 1s - loss: 0.2940 - acc: 0.8790 - binary_crossentropy: 0.2940 - val_loss: 0.3286 - val_acc: 0.8598 - val_binary_crossentropy: 0.3286
# Epoch 11/20
# 25000/25000 - 1s - loss: 0.2921 - acc: 0.8796 - binary_crossentropy: 0.2921 - val_loss: 0.3302 - val_acc: 0.8592 - val_binary_crossentropy: 0.3302
# Epoch 12/20
# 25000/25000 - 1s - loss: 0.2899 - acc: 0.8802 - binary_crossentropy: 0.2899 - val_loss: 0.3283 - val_acc: 0.8590 - val_binary_crossentropy: 0.3283
# Epoch 13/20
# 25000/25000 - 1s - loss: 0.2893 - acc: 0.8810 - binary_crossentropy: 0.2893 - val_loss: 0.3354 - val_acc: 0.8569 - val_binary_crossentropy: 0.3354
# Epoch 14/20
# 25000/25000 - 1s - loss: 0.2872 - acc: 0.8818 - binary_crossentropy: 0.2872 - val_loss: 0.3283 - val_acc: 0.8589 - val_binary_crossentropy: 0.3283
# Epoch 15/20
# 25000/25000 - 1s - loss: 0.2846 - acc: 0.8822 - binary_crossentropy: 0.2846 - val_loss: 0.3285 - val_acc: 0.8593 - val_binary_crossentropy: 0.3285
# Epoch 16/20
# 25000/25000 - 1s - loss: 0.2838 - acc: 0.8820 - binary_crossentropy: 0.2838 - val_loss: 0.3286 - val_acc: 0.8592 - val_binary_crossentropy: 0.3286
# Epoch 17/20
# 25000/25000 - 1s - loss: 0.2810 - acc: 0.8829 - binary_crossentropy: 0.2810 - val_loss: 0.3291 - val_acc: 0.8593 - val_binary_crossentropy: 0.3291
# Epoch 18/20
# 25000/25000 - 0s - loss: 0.2780 - acc: 0.8857 - binary_crossentropy: 0.2780 - val_loss: 0.3303 - val_acc: 0.8590 - val_binary_crossentropy: 0.3303
# Epoch 19/20
# 25000/25000 - 0s - loss: 0.2765 - acc: 0.8853 - binary_crossentropy: 0.2765 - val_loss: 0.3299 - val_acc: 0.8594 - val_binary_crossentropy: 0.3299
# Epoch 20/20
# 25000/25000 - 0s - loss: 0.2734 - acc: 0.8860 - binary_crossentropy: 0.2734 - val_loss: 0.3306 - val_acc: 0.8586 - val_binary_crossentropy: 0.3306
# Train on 25000 samples, validate on 25000 samples
# Epoch 1/20
# 25000/25000 - 3s - loss: 0.4084 - acc: 0.8147 - binary_crossentropy: 0.4084 - val_loss: 0.3309 - val_acc: 0.8582 - val_binary_crossentropy: 0.3309
# Epoch 2/20
# 25000/25000 - 3s - loss: 0.2895 - acc: 0.8804 - binary_crossentropy: 0.2895 - val_loss: 0.3258 - val_acc: 0.8600 - val_binary_crossentropy: 0.3258
# Epoch 3/20
# 25000/25000 - 3s - loss: 0.2242 - acc: 0.9116 - binary_crossentropy: 0.2242 - val_loss: 0.3413 - val_acc: 0.8574 - val_binary_crossentropy: 0.3413
# Epoch 4/20
# 25000/25000 - 3s - loss: 0.1136 - acc: 0.9632 - binary_crossentropy: 0.1136 - val_loss: 0.4747 - val_acc: 0.8335 - val_binary_crossentropy: 0.4747
# Epoch 5/20
# 25000/25000 - 3s - loss: 0.0320 - acc: 0.9940 - binary_crossentropy: 0.0320 - val_loss: 0.5523 - val_acc: 0.8455 - val_binary_crossentropy: 0.5523
# Epoch 6/20
# 25000/25000 - 3s - loss: 0.0063 - acc: 0.9996 - binary_crossentropy: 0.0063 - val_loss: 0.6178 - val_acc: 0.8509 - val_binary_crossentropy: 0.6178
# Epoch 7/20
# 25000/25000 - 3s - loss: 0.0016 - acc: 0.9999 - binary_crossentropy: 0.0016 - val_loss: 0.6656 - val_acc: 0.8502 - val_binary_crossentropy: 0.6656
# Epoch 8/20
# 25000/25000 - 3s - loss: 8.1416e-04 - acc: 1.0000 - binary_crossentropy: 8.1416e-04 - val_loss: 0.6968 - val_acc: 0.8518 - val_binary_crossentropy: 0.6968
# Epoch 9/20
# 25000/25000 - 2s - loss: 5.4719e-04 - acc: 1.0000 - binary_crossentropy: 5.4719e-04 - val_loss: 0.7210 - val_acc: 0.8519 - val_binary_crossentropy: 0.7210
# Epoch 10/20
# 25000/25000 - 3s - loss: 4.0482e-04 - acc: 1.0000 - binary_crossentropy: 4.0482e-04 - val_loss: 0.7419 - val_acc: 0.8521 - val_binary_crossentropy: 0.7419
# Epoch 11/20
# 25000/25000 - 2s - loss: 3.1360e-04 - acc: 1.0000 - binary_crossentropy: 3.1360e-04 - val_loss: 0.7611 - val_acc: 0.8522 - val_binary_crossentropy: 0.7611
# Epoch 12/20
# 25000/25000 - 2s - loss: 2.4822e-04 - acc: 1.0000 - binary_crossentropy: 2.4822e-04 - val_loss: 0.7783 - val_acc: 0.8522 - val_binary_crossentropy: 0.7783
# Epoch 13/20
# 25000/25000 - 2s - loss: 2.0103e-04 - acc: 1.0000 - binary_crossentropy: 2.0103e-04 - val_loss: 0.7943 - val_acc: 0.8525 - val_binary_crossentropy: 0.7943
# Epoch 14/20
# 25000/25000 - 2s - loss: 1.6396e-04 - acc: 1.0000 - binary_crossentropy: 1.6396e-04 - val_loss: 0.8097 - val_acc: 0.8522 - val_binary_crossentropy: 0.8097
# Epoch 15/20
# 25000/25000 - 2s - loss: 1.3573e-04 - acc: 1.0000 - binary_crossentropy: 1.3573e-04 - val_loss: 0.8248 - val_acc: 0.8522 - val_binary_crossentropy: 0.8248
# Epoch 16/20
# 25000/25000 - 3s - loss: 1.1317e-04 - acc: 1.0000 - binary_crossentropy: 1.1317e-04 - val_loss: 0.8388 - val_acc: 0.8522 - val_binary_crossentropy: 0.8388
# Epoch 17/20
# 25000/25000 - 3s - loss: 9.5543e-05 - acc: 1.0000 - binary_crossentropy: 9.5543e-05 - val_loss: 0.8524 - val_acc: 0.8525 - val_binary_crossentropy: 0.8524
# Epoch 18/20
# 25000/25000 - 3s - loss: 8.1045e-05 - acc: 1.0000 - binary_crossentropy: 8.1045e-05 - val_loss: 0.8659 - val_acc: 0.8525 - val_binary_crossentropy: 0.8659
# Epoch 19/20
# 25000/25000 - 3s - loss: 6.9382e-05 - acc: 1.0000 - binary_crossentropy: 6.9382e-05 - val_loss: 0.8781 - val_acc: 0.8523 - val_binary_crossentropy: 0.8781
# Epoch 20/20
# 25000/25000 - 3s - loss: 5.9809e-05 - acc: 1.0000 - binary_crossentropy: 5.9809e-05 - val_loss: 0.8908 - val_acc: 0.8526 - val_binary_crossentropy: 0.8908
# Train on 25000 samples, validate on 25000 samples
# Epoch 1/20
# 25000/25000 - 4s - loss: 0.4369 - acc: 0.7928 - binary_crossentropy: 0.4369 - val_loss: 0.4809 - val_acc: 0.8454 - val_binary_crossentropy: 0.4809
# Epoch 2/20
# 25000/25000 - 4s - loss: 0.2397 - acc: 0.9058 - binary_crossentropy: 0.2397 - val_loss: 0.4085 - val_acc: 0.8528 - val_binary_crossentropy: 0.4085
# Epoch 3/20
# 25000/25000 - 4s - loss: 0.1662 - acc: 0.9426 - binary_crossentropy: 0.1662 - val_loss: 0.3633 - val_acc: 0.8479 - val_binary_crossentropy: 0.3633
# Epoch 4/20
# 25000/25000 - 3s - loss: 0.0999 - acc: 0.9706 - binary_crossentropy: 0.0999 - val_loss: 0.3409 - val_acc: 0.8504 - val_binary_crossentropy: 0.3409
# Epoch 5/20
# 25000/25000 - 3s - loss: 0.0480 - acc: 0.9887 - binary_crossentropy: 0.0480 - val_loss: 0.3761 - val_acc: 0.8442 - val_binary_crossentropy: 0.3761
# Epoch 6/20
# 25000/25000 - 4s - loss: 0.0207 - acc: 0.9963 - binary_crossentropy: 0.0207 - val_loss: 0.4487 - val_acc: 0.8516 - val_binary_crossentropy: 0.4487
# Epoch 7/20
# 25000/25000 - 3s - loss: 0.0118 - acc: 0.9979 - binary_crossentropy: 0.0118 - val_loss: 0.5370 - val_acc: 0.8495 - val_binary_crossentropy: 0.5370
# Epoch 8/20
# 25000/25000 - 4s - loss: 0.0104 - acc: 0.9978 - binary_crossentropy: 0.0104 - val_loss: 0.6266 - val_acc: 0.8450 - val_binary_crossentropy: 0.6266
# Epoch 9/20
# 25000/25000 - 4s - loss: 0.0172 - acc: 0.9947 - binary_crossentropy: 0.0172 - val_loss: 0.6187 - val_acc: 0.8459 - val_binary_crossentropy: 0.6187
# Epoch 10/20
# 25000/25000 - 4s - loss: 0.0150 - acc: 0.9955 - binary_crossentropy: 0.0150 - val_loss: 0.6392 - val_acc: 0.8482 - val_binary_crossentropy: 0.6392
# Epoch 11/20
# 25000/25000 - 3s - loss: 0.0092 - acc: 0.9978 - binary_crossentropy: 0.0092 - val_loss: 0.6984 - val_acc: 0.8456 - val_binary_crossentropy: 0.6984
# Epoch 12/20
# 25000/25000 - 3s - loss: 0.0065 - acc: 0.9986 - binary_crossentropy: 0.0065 - val_loss: 0.7661 - val_acc: 0.8485 - val_binary_crossentropy: 0.7661
# Epoch 13/20
# 25000/25000 - 3s - loss: 0.0060 - acc: 0.9986 - binary_crossentropy: 0.0060 - val_loss: 0.8003 - val_acc: 0.8456 - val_binary_crossentropy: 0.8003
# Epoch 14/20
# 25000/25000 - 3s - loss: 0.0080 - acc: 0.9974 - binary_crossentropy: 0.0080 - val_loss: 0.8052 - val_acc: 0.8417 - val_binary_crossentropy: 0.8052
# Epoch 15/20
# 25000/25000 - 3s - loss: 0.0093 - acc: 0.9973 - binary_crossentropy: 0.0093 - val_loss: 0.7963 - val_acc: 0.8421 - val_binary_crossentropy: 0.7963
# Epoch 16/20
# 25000/25000 - 3s - loss: 0.0111 - acc: 0.9965 - binary_crossentropy: 0.0111 - val_loss: 0.8007 - val_acc: 0.8458 - val_binary_crossentropy: 0.8007
# Epoch 17/20
# 25000/25000 - 3s - loss: 0.0071 - acc: 0.9980 - binary_crossentropy: 0.0071 - val_loss: 0.8060 - val_acc: 0.8488 - val_binary_crossentropy: 0.8060
# Epoch 18/20
# 25000/25000 - 3s - loss: 0.0035 - acc: 0.9993 - binary_crossentropy: 0.0035 - val_loss: 0.9214 - val_acc: 0.8434 - val_binary_crossentropy: 0.9214
# Epoch 19/20
# 25000/25000 - 3s - loss: 0.0030 - acc: 0.9992 - binary_crossentropy: 0.0030 - val_loss: 0.9442 - val_acc: 0.8469 - val_binary_crossentropy: 0.9442
# Epoch 20/20
# 25000/25000 - 3s - loss: 0.0021 - acc: 0.9994 - binary_crossentropy: 0.0021 - val_loss: 0.9452 - val_acc: 0.8476 - val_binary_crossentropy: 0.9452
